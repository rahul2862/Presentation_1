# %% [markdown]
# # Data Analysis:
#
# - Data Analysis is a process of studying, cleaning, modeling, and transforming data with the purpose of finding useful information, suggesting conclusions, and supporting decision-making.

# %% [markdown]
# # This are the step are used for Analysis:
# - Data Collection
# - Data Processing
# - Data Cleaning
# - Data Analysis
# - Communication

# %% [markdown]
# # Tools Used in Data Analysis
# - Microsoft Excel
# - Python
# - R
# - Jupyter Notebook
# - Apache Spark
# - SAS
# - Microsoft Power BI
# - Tableau
# - KNIME

# %% [markdown]
# # Introduction To Python Visualization
#
# - Python, known for its simplicity and flexibility
# - It has become a popular choice for data analysis and visualization.
# - Its rich ecosystem of libraries and tools makes it possible to create a wide range of visualizations, from basic graphs to interactive dashboards.
# - Whether you're a data analyst, a scientist, a business professional, or just someone intrigued by the world of data.

# %% [markdown]
# # Data Wrangling
# * Getting & Reading data from different sources.
# * Cleaning Data
# * Shaping & Structuring Data
# * Storing Data
#
# There are many tools & libraries available for data wrangling. Tools like rapidminer & libraries like pandas. Organizations find libraries more suited because of flexibility.

# %% [markdown]
# # Pandas
# * High Performance, Easy-to-use open source library for Data Analysis
# * Creates tabular format of data from different sources like csv, json, database.
# * Have utilities for descriptive statistics, aggregation, handling missing data
# * Database utilities like merge, join are available
# * Fast, Programmable & Easy alternative to spreadsheets

# %% [markdown]
# # We'll explore various libraries such as
#
# **Matplotlib** :
#
# is one of the most popular and foundational libraries for creating static, interactive, and animated visualizations.
# It provides a wide range of plot types, customization options, and control over every aspect of the visualization.
#
# **Seaborn** :
#
# Built on top of Matplotlib, Seaborn specializes in creating aesthetically pleasing statistical visualizations.
# It simplifies the process of generating complex visualizations like heatmaps, pair plots, and violin plots.
#
# **Plotly** :
#
# Plotly is known for interactive and web-based visualizations.
# It offers both Python and JavaScript APIs, allowing you to create interactive plots that respond to user actions, making it suitable for dashboards and web applications.
# Pandas Plotting:
#
# The Pandas library includes built-in plotting functions that allow you to create basic visualizations directly from DataFrame objects.

# %% [markdown]
# # Types of Visualizations Python Can Create :
# - Line Plots
# - Bar Charts
# - Pie Charts
# - Scatter Plots
# - Histograms
# - Heatmaps
# - Box Plots

# %% [markdown]
# # Here are some real-world use cases for Python visualization
#
# 1.**Financial Data Analysis:**
#    - **Tool:** Matplotlib, Seaborn, Plotly
#    - **Use Case:** Visualizing stock price trends, portfolio performance, and financial market data. Plot candlestick charts, line graphs, and scatter plots to analyze financial data.
#
# **2. Healthcare Data Visualization:**
#    - **Tool:** Matplotlib, Seaborn, Plotly
#    - **Use Case:** Creating medical dashboards, visualizing patient data, and tracking disease outbreaks. Visualize patient demographics, disease prevalence, and treatment outcomes.
#
# **3. E-commerce Analytics:**
#    - **Tool:** Plotly, Matplotlib, Pandas
#    - **Use Case:** Analyzing customer behavior, sales trends, and product performance. Create interactive dashboards to monitor key performance indicators (KPIs) like conversion rates and customer retention.
#
# **4. Climate Data Visualization:**
#    - **Tool:** Cartopy, Matplotlib, Plotly
#    - **Use Case:** Visualizing climate data such as temperature patterns, rainfall, and sea-level rise. Create maps, heatmaps, and time series plots to understand climate change.
#
# **5. Social Media Analytics:**
#    - **Tool:** Plotly, Seaborn, NetworkX
#    - **Use Case:** Analyzing social media engagement, sentiment analysis, and network connections. Visualize network graphs, word clouds, and sentiment trends.
#
# **6. Scientific Research:**
#    - **Tool:** Matplotlib, Plotly, Mayavi
#    - **Use Case:** Visualizing experimental results, simulations, and scientific data. Create 3D plots, contour plots, and heatmaps to represent scientific findings.
#
# **7. Marketing Campaign Analysis:**
#    - **Tool:** Plotly, Matplotlib, Seaborn
#    - **Use Case:** Evaluating the effectiveness of marketing campaigns, A/B testing, and customer segmentation. Visualize conversion funnels, click-through rates, and customer segments.
#
# **8. Geospatial Data Visualization:**
#    - **Tool:** Folium, Plotly, Matplotlib
#    - **Use Case:** Mapping and geospatial analysis, including visualizing geographic data like population density, urban planning, and geographical features.
#
# **9. Retail Inventory Management:**
#    - **Tool:** Matplotlib, Seaborn, Pandas
#    - **Use Case:** Visualizing inventory levels, demand forecasting, and sales trends. Create bar charts, time series plots, and inventory heatmaps.
#
# **10. Machine Learning Model Evaluation:**
#      - **Tool:** Scikit-learn, Yellowbrick
#      - **Use Case:** Evaluating machine learning model performance through visualizations like ROC  curves, confusion matrices, and feature importances.
#
# **11. Network Analysis:**
#     - **Tool:** NetworkX, Plotly
#     - **Use Case:** Analyzing social networks, transportation networks, or cybersecurity. Visualize network structures, identify central nodes, and detect anomalies.

# %% [markdown]
# # Data cleaning using Python in Titanic Data

# %% [markdown]
# ### Import the Necessary libraries for data cleaning

# %%
## Data Analysis libraries

import pandas as pd
import numpy as np

## Data Visualization libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Rahul\titanic_1.csv")
data.head()
# Out:
#    PassengerID  survived  pclass     sex   age  sibsp  parch     fare  \
# 0            0         0       3    male  22.0      1      0   7.2500
# 1            1         1       1  female  38.0      1      0  71.2833
# 2            2         1       3  female  26.0      0      0   7.9250
# 3            3         1       1  female  35.0      1      0  53.1000
# 4            4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Issues with data
#
# 1. Missing value
# 2. Renaming the columns
# 3. Duplicated columns should be dropped
# 4. Check for Duplicate rows
# 5. Age should be an integer
# 6. Round the Fare column to 2 decimal
# 7. Passenger ID rearranges with proper number
# 8. Capitalize the column names
# 9. Replace the value in the column porperly
# 10. Sex and who Column are repeated.
# 11. Verify the data types of the column are proper
# 12. Alone and Sibsp

# %% [markdown]
# # Dropping the duplicate and unnecessary columns

# %%
data.columns
# Out:
# Index(['PassengerID', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# 1. Class and pclass columns are duplicated
# 2. survived and alive are duplicate
# 3. embarked and embark_town are duplicate
# 4. Solution is delete the duplicate columns from the data

# %%
cols = ['pclass', 'alive', 'embarked']
cols
# Out:
# ['pclass', 'alive', 'embarked']

# %%
data = data.drop(cols, axis = 1)
data.head()
# Out:
#    PassengerID  survived     sex   age  sibsp  parch     fare  class    who  \
# 0            0         0    male  22.0      1      0   7.2500  Third    man
# 1            1         1  female  38.0      1      0  71.2833  First  woman
# 2            2         1  female  26.0      0      0   7.9250  Third  woman
# 3            3         1  female  35.0      1      0  53.1000  First  woman
# 4            4         0    male  35.0      0      0   8.0500  Third    man
#
#    adult_male deck  embark_town  alone
# 0        True  NaN  Southampton  False
# 1       False    C    Cherbourg  False
# 2       False  NaN  Southampton   True
# 3       False    C  Southampton  False
# 4        True  NaN  Southampton   True

# %% [markdown]
# ## Delete the duplicate rows of the data

# %%
### data with original rows and columns
data.shape
# Out:
# (891, 13)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerID, survived, sex, age, sibsp, parch, fare, class, who, adult_male, deck, embark_town, alone]
# Index: []

# %% [markdown]
# - The above output is an empty DataFrame with only column names and no values present in the rows.
# - This indicates that we do not have any duplicated rows present in the data

# %% [markdown]
# ### Capitalize the columns

# %%
data.columns = data.columns.str.capitalize()
data.head()
# Out:
#    Passengerid  Survived     Sex   Age  Sibsp  Parch     Fare  Class    Who  \
# 0            0         0    male  22.0      1      0   7.2500  Third    man
# 1            1         1  female  38.0      1      0  71.2833  First  woman
# 2            2         1  female  26.0      0      0   7.9250  Third  woman
# 3            3         1  female  35.0      1      0  53.1000  First  woman
# 4            4         0    male  35.0      0      0   8.0500  Third    man
#
#    Adult_male Deck  Embark_town  Alone
# 0        True  NaN  Southampton  False
# 1       False    C    Cherbourg  False
# 2       False  NaN  Southampton   True
# 3       False    C  Southampton  False
# 4        True  NaN  Southampton   True

# %%
s = 'hello python'
s.capitalize()
# Out:
# 'Hello python'

# %%
s.title()
# Out:
# 'Hello Python'

# %%
data.columns
# Out:
# Index(['Passengerid', 'Survived', 'Sex', 'Age', 'Sibsp', 'Parch', 'Fare',
#        'Class', 'Who', 'Adult_male', 'Deck', 'Embark_town', 'Alone'],
#       dtype='object')

# %% [markdown]
# ### Rename the columns of the data

# %%
dic = {
    'Sibsp' : 'Siblings/Spouse',
    'Parch' : 'Parents/Children',
    'Class' : 'Passenger Class'
}
dic
# Out:
# {'Sibsp': 'Siblings/Spouse',
#  'Parch': 'Parents/Children',
#  'Class': 'Passenger Class'}

# %%
data = data.rename(dic, axis = 1)
data.head()
# Out:
#    Passengerid  Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0         0    male  22.0                1                 0
# 1            1         1  female  38.0                1                 0
# 2            2         1  female  26.0                0                 0
# 3            3         1  female  35.0                1                 0
# 4            4         0    male  35.0                0                 0
#
#       Fare Passenger Class    Who  Adult_male Deck  Embark_town  Alone
# 0   7.2500           Third    man        True  NaN  Southampton  False
# 1  71.2833           First  woman       False    C    Cherbourg  False
# 2   7.9250           Third  woman       False  NaN  Southampton   True
# 3  53.1000           First  woman       False    C  Southampton  False
# 4   8.0500           Third    man        True  NaN  Southampton   True

# %% [markdown]
# ### Replace male - Male, female - Female in Sex column
# ### Replace 0 - No and 1 - Yes in the Survived column

# %%
dic1 = {
    'male' : 'Male',
    'female' : 'Female'
}
dic1
# Out:
# {'male': 'Male', 'female': 'Female'}

# %%
dic2 = {
    0 : 'No',
    1 : 'Yes'
}
dic2
# Out:
# {0: 'No', 1: 'Yes'}

# %%
data['Sex'] = data['Sex'].replace(dic1)
data.head()
# Out:
#    Passengerid  Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0         0    Male  22.0                1                 0
# 1            1         1  Female  38.0                1                 0
# 2            2         1  Female  26.0                0                 0
# 3            3         1  Female  35.0                1                 0
# 4            4         0    Male  35.0                0                 0
#
#       Fare Passenger Class    Who  Adult_male Deck  Embark_town  Alone
# 0   7.2500           Third    man        True  NaN  Southampton  False
# 1  71.2833           First  woman       False    C    Cherbourg  False
# 2   7.9250           Third  woman       False  NaN  Southampton   True
# 3  53.1000           First  woman       False    C  Southampton  False
# 4   8.0500           Third    man        True  NaN  Southampton   True

# %%
data['Survived'] = data['Survived'].replace(dic2)
data.head()
# Out:
#    Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0       No    Male  22.0                1                 0
# 1            1      Yes  Female  38.0                1                 0
# 2            2      Yes  Female  26.0                0                 0
# 3            3      Yes  Female  35.0                1                 0
# 4            4       No    Male  35.0                0                 0
#
#       Fare Passenger Class    Who  Adult_male Deck  Embark_town  Alone
# 0   7.2500           Third    man        True  NaN  Southampton  False
# 1  71.2833           First  woman       False    C    Cherbourg  False
# 2   7.9250           Third  woman       False  NaN  Southampton   True
# 3  53.1000           First  woman       False    C  Southampton  False
# 4   8.0500           Third    man        True  NaN  Southampton   True

# %% [markdown]
# ### Round the value of fare column to 2 decimal places

# %%
score = 72.45672389
score
# Out:
# 72.45672389

# %%
round(score, 3)
# Out:
# 72.457

# %%
data['Fare'] = round(data['Fare'], 2)
data.head(15)
# Out:
#     Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0             0       No    Male  22.0                1                 0
# 1             1      Yes  Female  38.0                1                 0
# 2             2      Yes  Female  26.0                0                 0
# 3             3      Yes  Female  35.0                1                 0
# 4             4       No    Male  35.0                0                 0
# 5             5       No    Male   NaN                0                 0
# 6             6       No    Male  54.0                0                 0
# 7             7       No    Male   2.0                3                 1
# 8             8      Yes  Female  27.0                0                 2
# 9             9      Yes  Female  14.0                1                 0
# 10           10      Yes  Female   4.0                1                 1
# 11           11      Yes  Female  58.0                0                 0
# 12           12       No    Male  20.0                0                 0
# 13           13       No    Male  39.0                1                 5
# 14           14       No  Female  14.0                0                 0
#
#      Fare Passenger Class    Who  Adult_male Deck  Embark_town  Alone
# 0    7.25           Third    man        True  NaN  Southampton  False
# 1   71.28           First  woman       False    C    Cherbourg  False
# 2    7.92           Third  woman       False  NaN  Southampton   True
# 3   53.10           First  woman       False    C  Southampton  False
# 4    8.05           Third    man        True  NaN  Southampton   True
# 5    8.46           Third    man        True  NaN   Queenstown   True
# 6   51.86           First    man        True    E  Southampton   True
# 7   21.08           Third  child       False  NaN  Southampton  False
# 8   11.13           Third  woman       False  NaN  Southampton  False
# 9   30.07          Second  child       False  NaN    Cherbourg  False
# 10  16.70           Third  child       False    G  Southampton  False
# 11  26.55           First  woman       False    C  Southampton   True
# 12   8.05           Third    man        True  NaN  Southampton   True
# 13  31.28           Third    man        True  NaN  Southampton  False
# 14   7.85           Third  child       False  NaN  Southampton   True

# %% [markdown]
# ### Investigate the deck column

# %%
data['Deck'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: Deck, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Passengerid       891 non-null    int64
#  1   Survived          891 non-null    object
#  2   Sex               891 non-null    object
#  3   Age               714 non-null    float64
#  4   Siblings/Spouse   891 non-null    int64
#  5   Parents/Children  891 non-null    int64
#  6   Fare              891 non-null    float64
#  7   Passenger Class   891 non-null    object
#  8   Who               891 non-null    object
#  9   Adult_male        891 non-null    bool
#  10  Deck              203 non-null    object
#  11  Embark_town       889 non-null    object
#  12  Alone             891 non-null    bool
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 78.4+ KB

# %%
688 / 891 * 100
# Out:
# 77.21661054994388

# %% [markdown]
# - 77.21 % values are missing the deck columns, hence delete the deck column from the data

# %%
data = data.drop('Deck', axis = 1)
data.head()
# Out:
#    Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0       No    Male  22.0                1                 0
# 1            1      Yes  Female  38.0                1                 0
# 2            2      Yes  Female  26.0                0                 0
# 3            3      Yes  Female  35.0                1                 0
# 4            4       No    Male  35.0                0                 0
#
#     Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 0   7.25           Third    man        True  Southampton  False
# 1  71.28           First  woman       False    Cherbourg  False
# 2   7.92           Third  woman       False  Southampton   True
# 3  53.10           First  woman       False  Southampton  False
# 4   8.05           Third    man        True  Southampton   True

# %% [markdown]
# ### Age should present as an integer column

# %%
## Checking the unique values present in the age column to decide whether age should be int or float

data['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# - There are values in age like 0.67, 0.42, 0.92 etc. indicating that the passengers are travelling with babies.
# - If the age is converted from float to int then all the values like 0.67, 0.42 etc will become 0.(after losing the decimal values)

# %%
data.head()
# Out:
#    Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0       No    Male  22.0                1                 0
# 1            1      Yes  Female  38.0                1                 0
# 2            2      Yes  Female  26.0                0                 0
# 3            3      Yes  Female  35.0                1                 0
# 4            4       No    Male  35.0                0                 0
#
#     Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 0   7.25           Third    man        True  Southampton  False
# 1  71.28           First  woman       False    Cherbourg  False
# 2   7.92           Third  woman       False  Southampton   True
# 3  53.10           First  woman       False  Southampton  False
# 4   8.05           Third    man        True  Southampton   True

# %% [markdown]
# ### Check wherther Sex and Who columns are duplicate

# %%
data['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %% [markdown]
# - The unique values of Sex and Who column are different indicating that Sex and Who are not duplicate columns. Hence, we cannot drop these columns

# %% [markdown]
# ## Verify the data types of the columns are proper

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Passengerid       891 non-null    int64
#  1   Survived          891 non-null    object
#  2   Sex               891 non-null    object
#  3   Age               714 non-null    float64
#  4   Siblings/Spouse   891 non-null    int64
#  5   Parents/Children  891 non-null    int64
#  6   Fare              891 non-null    float64
#  7   Passenger Class   891 non-null    object
#  8   Who               891 non-null    object
#  9   Adult_male        891 non-null    bool
#  10  Embark_town       889 non-null    object
#  11  Alone             891 non-null    bool
# dtypes: bool(2), float64(2), int64(3), object(5)
# memory usage: 71.5+ KB

# %%
data
# Out:
#      Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0              0       No    Male  22.0                1                 0
# 1              1      Yes  Female  38.0                1                 0
# 2              2      Yes  Female  26.0                0                 0
# 3              3      Yes  Female  35.0                1                 0
# 4              4       No    Male  35.0                0                 0
# ..           ...      ...     ...   ...              ...               ...
# 886          886       No    Male  27.0                0                 0
# 887          887      Yes  Female  19.0                0                 0
# 888          888       No  Female   NaN                1                 2
# 889          889      Yes    Male  26.0                0                 0
# 890          890       No    Male  32.0                0                 0
#
#       Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 0     7.25           Third    man        True  Southampton  False
# 1    71.28           First  woman       False    Cherbourg  False
# 2     7.92           Third  woman       False  Southampton   True
# 3    53.10           First  woman       False  Southampton  False
# 4     8.05           Third    man        True  Southampton   True
# ..     ...             ...    ...         ...          ...    ...
# 886  13.00          Second    man        True  Southampton   True
# 887  30.00           First  woman       False  Southampton   True
# 888  23.45           Third  woman       False  Southampton  False
# 889  30.00           First    man        True    Cherbourg   True
# 890   7.75           Third    man        True   Queenstown   True
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Filter the data where the passengers are travelling with their children

# %%
## Boolean Indexing
## data[data['Who'] == 'child']
data[data['Who'] == 'child']
# Out:
#      Passengerid Survived     Sex    Age  Siblings/Spouse  Parents/Children  \
# 7              7       No    Male   2.00                3                 1
# 9              9      Yes  Female  14.00                1                 0
# 10            10      Yes  Female   4.00                1                 1
# 14            14       No  Female  14.00                0                 0
# 16            16       No    Male   2.00                4                 1
# ..           ...      ...     ...    ...              ...               ...
# 831          831      Yes    Male   0.83                1                 1
# 850          850       No    Male   4.00                4                 2
# 852          852       No  Female   9.00                1                 1
# 869          869      Yes    Male   4.00                1                 1
# 875          875      Yes  Female  15.00                0                 0
#
#       Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 7    21.08           Third  child       False  Southampton  False
# 9    30.07          Second  child       False    Cherbourg  False
# 10   16.70           Third  child       False  Southampton  False
# 14    7.85           Third  child       False  Southampton   True
# 16   29.12           Third  child       False   Queenstown  False
# ..     ...             ...    ...         ...          ...    ...
# 831  18.75          Second  child       False  Southampton  False
# 850  31.28           Third  child       False  Southampton  False
# 852  15.25           Third  child       False    Cherbourg  False
# 869  11.13           Third  child       False  Southampton  False
# 875   7.22           Third  child       False    Cherbourg   True
#
# [83 rows x 12 columns]

# %% [markdown]
# - The titanic ship was carrying 83 children in it.

# %% [markdown]
# ### How many Male Children are travelling in titanic

# %%
data[(data['Sex'] == 'Male') & (data['Who'] == 'child')]
# Out:
#      Passengerid Survived   Sex    Age  Siblings/Spouse  Parents/Children  \
# 7              7       No  Male   2.00                3                 1
# 16            16       No  Male   2.00                4                 1
# 50            50       No  Male   7.00                4                 1
# 59            59       No  Male  11.00                5                 2
# 63            63       No  Male   4.00                3                 2
# 78            78      Yes  Male   0.83                0                 2
# 125          125      Yes  Male  12.00                1                 0
# 164          164       No  Male   1.00                4                 1
# 165          165      Yes  Male   9.00                0                 2
# 171          171       No  Male   4.00                4                 1
# 182          182       No  Male   9.00                4                 2
# 183          183      Yes  Male   1.00                2                 1
# 193          193      Yes  Male   3.00                1                 1
# 261          261      Yes  Male   3.00                4                 2
# 278          278       No  Male   7.00                4                 1
# 305          305      Yes  Male   0.92                1                 2
# 340          340      Yes  Male   2.00                1                 1
# 348          348      Yes  Male   3.00                1                 1
# 352          352       No  Male  15.00                1                 1
# 386          386       No  Male   1.00                5                 2
# 407          407      Yes  Male   3.00                1                 1
# 445          445      Yes  Male   4.00                0                 2
# 480          480       No  Male   9.00                5                 2
# 489          489      Yes  Male   9.00                1                 1
# 549          549      Yes  Male   8.00                1                 1
# 683          683       No  Male  14.00                5                 2
# 686          686       No  Male  14.00                4                 1
# 731          731       No  Male  11.00                0                 0
# 751          751      Yes  Male   6.00                0                 1
# 755          755      Yes  Male   0.67                1                 1
# 787          787       No  Male   8.00                4                 1
# 788          788      Yes  Male   1.00                1                 2
# 802          802      Yes  Male  11.00                1                 2
# 803          803      Yes  Male   0.42                0                 1
# 819          819       No  Male  10.00                3                 2
# 824          824       No  Male   2.00                4                 1
# 827          827      Yes  Male   1.00                0                 2
# 831          831      Yes  Male   0.83                1                 1
# 850          850       No  Male   4.00                4                 2
# 869          869      Yes  Male   4.00                1                 1
#
#        Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 7     21.08           Third  child       False  Southampton  False
# 16    29.12           Third  child       False   Queenstown  False
# 50    39.69           Third  child       False  Southampton  False
# 59    46.90           Third  child       False  Southampton  False
# 63    27.90           Third  child       False  Southampton  False
# 78    29.00          Second  child       False  Southampton  False
# 125   11.24           Third  child       False    Cherbourg  False
# 164   39.69           Third  child       False  Southampton  False
# 165   20.52           Third  child       False  Southampton  False
# 171   29.12           Third  child       False   Queenstown  False
# 182   31.39           Third  child       False  Southampton  False
# 183   39.00          Second  child       False  Southampton  False
# 193   26.00          Second  child       False  Southampton  False
# 261   31.39           Third  child       False  Southampton  False
# 278   29.12           Third  child       False   Queenstown  False
# 305  151.55           First  child       False  Southampton  False
# 340   26.00          Second  child       False  Southampton  False
# 348   15.90           Third  child       False  Southampton  False
# 352    7.23           Third  child       False    Cherbourg  False
# 386   46.90           Third  child       False  Southampton  False
# 407   18.75          Second  child       False  Southampton  False
# 445   81.86           First  child       False  Southampton  False
# 480   46.90           Third  child       False  Southampton  False
# 489   15.90           Third  child       False  Southampton  False
# 549   36.75          Second  child       False  Southampton  False
# 683   46.90           Third  child       False  Southampton  False
# 686   39.69           Third  child       False  Southampton  False
# 731   18.79           Third  child       False    Cherbourg   True
# 751   12.48           Third  child       False  Southampton  False
# 755   14.50          Second  child       False  Southampton  False
# 787   29.12           Third  child       False   Queenstown  False
# 788   20.58           Third  child       False  Southampton  False
# 802  120.00           First  child       False  Southampton  False
# 803    8.52           Third  child       False    Cherbourg  False
# 819   27.90           Third  child       False  Southampton  False
# 824   39.69           Third  child       False  Southampton  False
# 827   37.00          Second  child       False    Cherbourg  False
# 831   18.75          Second  child       False  Southampton  False
# 850   31.28           Third  child       False  Southampton  False
# 869   11.13           Third  child       False  Southampton  False

# %%
data[(data['Sex'] == 'Male') & (data['Who'] == 'child')].count()
# Out:
# Passengerid         40
# Survived            40
# Sex                 40
# Age                 40
# Siblings/Spouse     40
# Parents/Children    40
# Fare                40
# Passenger Class     40
# Who                 40
# Adult_male          40
# Embark_town         40
# Alone               40
# dtype: int64

# %% [markdown]
# - 40 Male Children are travelling in titanic
# - Total children 83, Male Children - 40, Female children = 83 - 40 = 43

# %%
data.head()
# Out:
#    Passengerid Survived     Sex   Age  Siblings/Spouse  Parents/Children  \
# 0            0       No    Male  22.0                1                 0
# 1            1      Yes  Female  38.0                1                 0
# 2            2      Yes  Female  26.0                0                 0
# 3            3      Yes  Female  35.0                1                 0
# 4            4       No    Male  35.0                0                 0
#
#     Fare Passenger Class    Who  Adult_male  Embark_town  Alone
# 0   7.25           Third    man        True  Southampton  False
# 1  71.28           First  woman       False    Cherbourg  False
# 2   7.92           Third  woman       False  Southampton   True
# 3  53.10           First  woman       False  Southampton  False
# 4   8.05           Third    man        True  Southampton   True

# %% [markdown]
# ## Column Indexing

# %%
data['Sex']
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3      Female
# 4        Male
#         ...
# 886      Male
# 887    Female
# 888    Female
# 889      Male
# 890      Male
# Name: Sex, Length: 891, dtype: object

# %%
data[['Sex', 'Survived']]
# Out:
#         Sex Survived
# 0      Male       No
# 1    Female      Yes
# 2    Female      Yes
# 3    Female      Yes
# 4      Male       No
# ..      ...      ...
# 886    Male       No
# 887  Female      Yes
# 888  Female       No
# 889    Male      Yes
# 890    Male       No
#
# [891 rows x 2 columns]

# %% [markdown]
# #  Learning URL

# %% [markdown]
# https://www.learndatasci.com/best-data-analytics-courses/
#
# https://www.geeksforgeeks.org/pandas-tutorial/
#
# https://www.w3schools.com/python/pandas/default.asp
#
# https://www.geeksforgeeks.org/python-data-analysis-using-pandas/?ref=shm
